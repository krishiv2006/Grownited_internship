# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data provided in the prompt
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Sales': [12000, 15000, 18000, 14000, 22000, 25000]
}
df = pd.DataFrame(data)

print("DataFrame created successfully:")
display(df)
# Out:
# DataFrame created successfully:
#   Month  Sales
# 0   Jan  12000
# 1   Feb  15000
# 2   Mar  18000
# 3   Apr  14000
# 4   May  22000
# 5   Jun  25000

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Month', y='Sales', data=df, marker='o')
plt.title('Monthly Sales Trend (Line Chart)')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='Sales', data=df, palette='viridis')
plt.title('Monthly Sales (Bar Chart)')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(axis='y')
plt.show()
# Out:
# /tmp/ipykernel_2257/2068900264.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Month', y='Sales', data=df, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
plt.fill_between(df['Month'], df['Sales'], color='skyblue', alpha=0.4)
sns.lineplot(x='Month', y='Sales', data=df, color='Slateblue', alpha=0.6, marker='o')
plt.title('Monthly Sales Trend (Area Chart)')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.show()
